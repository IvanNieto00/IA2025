# %% [markdown]
# ## Redes Neuronales para regresión
#
# Basado en notebook de Noelia Echeverría.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import datasets
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import StandardScaler

from keras.models import Sequential
from keras.layers import Dense

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# Por ahora vamos a trabajar con un Toy Dataset. Para cargarlo y poder trabajar con él debemos poner `datasets.load_boston()` <br>
#
# Al hacerlo, se carga en una variable un objeto de tipo `bunch`. Hay 4 keys relevantes en este objeto.
# > * `data`
# * `target`
# * `feature_names`
# * `DESCR`
#
# ![separador](https://i.imgur.com/4gX5WFr.png)
#
# ### **Feature Names**
#
# **¿Qué significan los feature names?** <br>
#
# * **CRIM** = Tasa de crimen per-capita del barrio
# * **ZN** = proporción de terrenos residenciales divididos en zonas para lotes de más de 25,000 pies cuadrados
# * **INDUS** = proporción de acres de negocios no minoristas por ciudad
# * **CHAS** = variable ficticia de Charles River (= 1 si el tramo limita el río, 0 de lo contrario)
# * **NOX** =  concentración de óxidos nítricos (partes por 10 millones)
# * **RM** = número promedio de habitaciones por vivienda
# * **AGE** = proporción de unidades ocupadas por sus propietarios construidas antes de 1940
# * **DIS** = Distancias ponderadas a cinco centros de empleo de Boston
# * **RAD** = índice de accesibilidad a las autopistas radiales
# * **TAX** = Tasa de impuesto a la propiedad de valor total por $ 10,000
# * **PTRATIO** =  colegios por localidad
# * **B** =  1000 (Bk - 0,63)^ 2, donde Bk es la proporción de negros por ciudad
# * **LSTAT** = porcentaje del status mas bajo de la poblacion
#
# Disclaimer: Este dataset tiene algunas columnas controversiales, de índole racista.

# %% [markdown]
# ### Transformamos a Pandas DataFrame

# %%
boston_df = pd.read_csv("https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv")

# %%
boston_df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %% [markdown]
# # Preprocesamiento
#
# (suele ser necesario, pero no lo vamos a ejecutar en clase)

# %% [markdown]
# ---
# #### Buscamos missing values
#
# ---

# %%
# buscamos valores nulos
print(boston_df.isnull().sum()) # --> NO hay valores nulos
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %% [markdown]
# ---
# Mostramos la estadística del dataset
#
# ---

# %%
print(boston_df.describe())
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             lstat        medv
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %% [markdown]
# ---
#
# #### Exploramos los datos
#
# El precio de las casas tiene una distribución "similar" a una distribución normal, con algunos outliers.
#
# ---

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
plt.hist(boston_df['medv'], bins=30)
plt.xlabel("Precio de las casas en miles de dolares")
plt.show()

# %% [markdown]
# ---
# #### Mapa de Calor (HeatMap) - Correlaciones entre las columnas.
#
# ---
# Podemos observar altas correlaciones entre el precio (PRICE) y :
# * RM (correlacion 0.7)  --> cantidad de habitaciones
# * LSTAT (correlacion -0.74) --> Porcentaje del nivel mas bajo de la poblacion
# * PTRATIO (correlacion -0.51) --> Cantidad de colegios en la ciudad
# * TAX (correlacion -0.47) --> impuestos
#
# ---

# %%
# Vamos a ver las correlaciones entre el precio y los features
correlation_matrix = boston_df.corr().round(2)
sns.heatmap(data=correlation_matrix, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ---
# #### Graficamos los features candidatos a entrenar nuestra red
#
# ---

# %%
plt.figure(figsize=(20, 10))

features = ['lstat', 'rm', 'ptratio', 'tax']
target = boston_df['medv']

for i, col in enumerate(features):
    plt.subplot(2, 2 , i+1)
    x = boston_df[col]
    y = target
    plt.scatter(x, y, marker='o')
    plt.title("Variacion en los precios de la casas")
    plt.xlabel(col)
    plt.ylabel('"Precio de las casas en miles de dolares')

# %% [markdown]
# ---
# Al graficar nos damos cuenta que:<br>
# * El precio de la casa se incrementa con el número de habitaciones (RM)
# * El precio se decrementa cuanto más empobrecida está la zona (LSTAT)
#
# * PTRATIO y TAX no nos brindan demasiada información del precio de la casa
#
# ---
#
# Para entrenar nuestra red vamos a utilizar RM y LSTAT
#
# ---

# %% [markdown]
# # Funciones para entrenamiento
#
# Vamos a definir algunas funciones para trabajar
#
# Armado de modelo para regresion:
#
# ```python
# model = Sequential()
# model.add(Dense(128, input_dim=n_train_dim, activation='relu'))
# model.add(Dense(1, activation='linear'))
#
#
# model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mae'])
# ```
#
#
# Entrenamiento del modelo:
#
# ```python
# result = model.fit(X_train, y_train, validation_split=0.2, epochs=100, verbose=1)
#
# ```
#
# Para obtener los resultados de loss:
#
# ```python
# loss = result.history['loss']
# val_loss = result.history['val_loss']
# ```
#
# Para ver los resultados de la métrica:
#
# ```python
# mae = result.history['mae']
# val_mae = result.history['val_mae']
#
# ```
#
# Para hacer predicciones sobre conjunto de test:
#
# ```python
# predictions = model.predict(X_test)
# ```

# %%
def myModel(X, y, random_state=1, scale=True, test_size=0.1):
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=random_state, test_size=test_size)
    scaler = StandardScaler().fit(X_train)

    if scale:
        X_train = scaler.transform(X_train)
        X_test = scaler.transform(X_test) # cuidado, al aplicar el standard scaler, los datos dejan de ser dataframes

    n_train_samples, n_train_dim = X_train.shape


    # Para regresion utilizamos una unica capa oculta
    model = Sequential()
    model.add(Dense(128, input_dim=n_train_dim, activation='relu'))
    model.add(Dense(1, activation='linear'))


    model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mae'])
    model.summary()

    return model, X_train, X_test, y_train, y_test

# %%
def trainMyModel(model, X_train, y_train):

    result = model.fit(X_train, y_train, validation_split=0.2, epochs=100, verbose=1)

    print("history.keys = ",result.history.keys())

    loss = result.history['loss']
    val_loss = result.history['val_loss']
    epochs = range(1, len(loss) + 1)

    plt.figure(figsize=(7,7))
    plt.plot(epochs, loss, 'b', label='Training loss')
    plt.plot(epochs, val_loss, 'r', label='Validation loss')
    plt.title('Training and validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Mean Square Error')
    plt.legend()
    plt.show()


    mae = result.history['mae']
    val_mae = result.history['val_mae']


    plt.figure(figsize=(7,7))
    plt.plot(epochs, mae, 'y', label='Training MAE')
    plt.plot(epochs, val_mae, 'r', label='Validation MAE')
    plt.title('Training and validation MAE')
    plt.xlabel('Epochs')
    plt.ylabel('Mean Absolute Error')
    plt.legend()
    plt.show()

# %%
def makePredictions(model, X_test, y_test):
    predictions = model.predict(X_test)

    y_test = np.array(y_test)

    predicted_value = np.array(predictions)
    predicted_value = predicted_value.reshape(max(predicted_value.shape), )

    return predicted_value

# %%
def plotPredictionsOnTwoAxes(predicted_value, X_test, y_test):

    data = np.array(X_test)  # ploteo con los datos sin estandarizar

    if (X_test.shape[1]==2) :
        data1 = data[:, 0]
        data2 = data[:, 1]
    else:
        data1 = data[:, 5]
        data2 = data[:, 12]
    true_value = np.array(y_test)
    plt.subplot(2, 1 , 1)
    plt.scatter(data1, true_value, marker='o', c='r')
    plt.scatter(data1, predicted_value, marker='o', c='b')
    plt.ylabel('"Precio de las casas en miles de dolares')
    plt.subplot(2, 1 , 2)
    plt.scatter(data2, true_value, marker='o', c='r')
    plt.scatter(data2, predicted_value, marker='o', c='b')
    plt.ylabel('"Precio de las casas en miles de dolares')
    plt.suptitle("Estimación de precios de casas - azul true value - red estimated value [DATOS DE TESTEO]")
    return data1, data2

# %%
def plotPredictionsSeparated(predicted_value, X_test, y_test):

    data = np.array(X_test)  # ploteo con los datos sin estandarizar

    if (X_test.shape[1]==2) :
        data1 = data[:, 0]
        data2 = data[:, 1]
    else:
        data1 = data[:, 5]
        data2 = data[:, 12]
    true_value = np.array(y_test)
    plt.subplot(2, 2 , 1)
    plt.scatter(data1, true_value, marker='o', c='r')
    plt.ylabel('Precio en miles de dolares')
    plt.title("True")
    plt.subplot(2, 2 , 2)
    plt.scatter(data1, predicted_value, marker='o', c='b')
    plt.ylabel('Precio en miles de dolares')
    plt.title("Predicted")
    plt.subplot(2, 2 , 3)
    plt.scatter(data2, true_value, marker='o', c='r')
    plt.ylabel('Precio en miles de dolares')
    plt.title("True")
    plt.subplot(2, 2 , 4)
    plt.scatter(data2, predicted_value, marker='o', c='b')
    plt.ylabel('Precio en miles de dolares')
    plt.title("Predicted")
    plt.suptitle("Estimación de precios de casas - azul true value - red estimated value [DATOS DE TESTEO]")
    return data1, data2

# %%
def plotTwoModels(data11, data12, true_value, predicted_value1, data21, data22, predicted_value2):
    plt.figure(figsize=(15,12))
    plt.subplot(2, 2 , 1)
    plt.scatter(data11, true_value, marker='o', c='r')
    plt.scatter(data11, predicted_value1, marker='o', c='b')
    plt.ylabel('Precio de las casas en miles de dolares')
    plt.title("True value - 2 parametros de entrenamiento - PRICE VS RM")
    plt.subplot(2, 2 , 2)
    plt.scatter(data12, true_value, marker='o', c='r')
    plt.scatter(data12, predicted_value1, marker='o', c='b')
    plt.ylabel('Precio de las casas en miles de dolares')
    plt.title("Predicted value - 2 parametros de entrenamiento - PRICE VS LSTAT")
    plt.suptitle("Estimación de precios de casas - azul true value - red estimated value [DATOS DE TESTEO]")
    plt.subplot(2, 2 , 3)
    plt.scatter(data21, true_value, marker='o', c='m')
    plt.scatter(data21, predicted_value2, marker='o', c='c')
    plt.ylabel('Precio de las casas en miles de dolares')
    plt.title("True value - 13 parametros de entrenamiento - PRICE VS RM")
    plt.subplot(2, 2 , 4)
    plt.scatter(data22, true_value, marker='o', c='m')
    plt.scatter(data22, predicted_value2, marker='o', c='c')
    plt.ylabel('"Precio de las casas en miles de dolares')
    plt.title("Predicted value - 13 parametros de entrenamiento - PRICE VS LSTAT")
    plt.suptitle("Estimación de precios de casas - Red entrenada con 2 parametros - Red Entrenada con 13 parametros")

# %% [markdown]
# ### **Modelo 1**
#
# #### 2 features de entrenamiento
#
# * `RM`
# * `LSTAT`

# %%
X = boston_df[["rm", "lstat"]]
y = boston_df["medv"]  # no es lo mismo que tenga 1 par de corchetes o dos pares de corchetes
model, X_train, X_test, y_train, y_test = myModel(X, y, random_state=1, scale=False)
trainMyModel(model, X_train, y_train)
predicted_value = makePredictions(model, X_test, y_test)
data11, data12 = plotPredictionsOnTwoAxes(predicted_value, X_test, y_test)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │           384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 513 (2.00 KB)
#  Trainable params: 513 (2.00 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - loss: 551.0875 - mae: 21.4755 - val_loss: 480.9322 - val_mae: 19.3089
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 470.0827 - mae: 19.3887 - val_loss: 407.7304 - val_mae: 17.1042
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 403.3426 - mae: 17.1054 - val_loss: 347.2028 - val_mae: 15.1137
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 335.4088 - mae: 15.3148 - val_loss: 299.1967 - val_mae: 13.4661
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 356.5534 - mae: 15.4341 - val_loss: 262.6223 - val_mae: 12.1653
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 250.1351 - mae: 12.7128 - val_loss: 236.6126 - val_mae: 11.3027
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 238.9693 - mae: 12.5603 - val_loss: 216.4340 - val_mae: 10.7158
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 218.0307 - mae: 11.8437 - val_loss: 198.9872 - val_mae: 10.1911
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 202.8955 - mae: 11.2583 - val_loss: 181.7279 - val_mae: 9.6735
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 183.2442 - mae: 10.5082 - val_loss: 165.5244 - val_mae: 9.1726
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 166.5512 - mae: 10.0506 - val_loss: 150.3394 - val_mae: 8.6758
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 149.2109 - mae: 9.3564 - val_loss: 135.9507 - val_mae: 8.1730
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 124.4454 - mae: 8.5574 - val_loss: 122.7266 - val_mae: 7.6794
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 112.4659 - mae: 8.0521 - val_loss: 110.3597 - val_mae: 7.2072
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 107.4328 - mae: 7.7349 - val_loss: 98.8431 - val_mae: 6.7366
# Epoch 16/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 89.6028 - mae: 6.9384 - val_loss: 88.5242 - val_mae: 6.2750
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 82.6177 - mae: 6.4278 - val_loss: 79.2767 - val_mae: 5.8406
# Epoch 18/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 76.3431 - mae: 6.0502 - val_loss: 71.3526 - val_mae: 5.4428
# Epoch 19/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 68.1538 - mae: 5.5293 - val_loss: 64.2570 - val_mae: 5.0753
# Epoch 20/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 56.0577 - mae: 5.0367 - val_loss: 58.4306 - val_mae: 4.8039
# Epoch 21/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 51.8555 - mae: 4.9979 - val_loss: 53.2141 - val_mae: 4.6092
# Epoch 22/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 44.0721 - mae: 4.4149 - val_loss: 49.3308 - val_mae: 4.4560
# Epoch 23/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 46.0152 - mae: 4.5872 - val_loss: 45.6480 - val_mae: 4.3495
# Epoch 24/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 39.5956 - mae: 4.2270 - val_loss: 42.8413 - val_mae: 4.2660
# Epoch 25/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 37.6125 - mae: 4.1233 - val_loss: 40.5418 - val_mae: 4.1918
# Epoch 26/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 34.8988 - mae: 4.0417 - val_loss: 39.4452 - val_mae: 4.1217
# Epoch 27/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 32.2188 - mae: 3.8886 - val_loss: 37.3417 - val_mae: 4.0814
# Epoch 28/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 34.2811 - mae: 4.0408 - val_loss: 36.0553 - val_mae: 4.0465
# Epoch 29/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 31.0796 - mae: 3.8185 - val_loss: 35.4683 - val_mae: 3.9541
# Epoch 30/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 35.4845 - mae: 3.9848 - val_loss: 34.3849 - val_mae: 3.9152
# Epoch 31/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 28.9747 - mae: 3.6590 - val_loss: 33.6162 - val_mae: 3.8871
# Epoch 32/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 28.1854 - mae: 3.6727 - val_loss: 33.3010 - val_mae: 3.8709
# Epoch 33/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 29.7982 - mae: 3.6987 - val_loss: 32.1407 - val_mae: 3.8402
# Epoch 34/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 30.4482 - mae: 3.7531 - val_loss: 31.9319 - val_mae: 3.8108
# Epoch 35/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 26.7928 - mae: 3.7283 - val_loss: 31.7122 - val_mae: 3.8038
# Epoch 36/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 26.8908 - mae: 3.6788 - val_loss: 30.5283 - val_mae: 3.7661
# Epoch 37/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 28.7402 - mae: 3.7696 - val_loss: 30.5562 - val_mae: 3.7541
# Epoch 38/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 33.3815 - mae: 3.8785 - val_loss: 30.5105 - val_mae: 3.7597
# Epoch 39/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.1496 - mae: 3.3673 - val_loss: 29.5846 - val_mae: 3.7035
# Epoch 40/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 25.3485 - mae: 3.6654 - val_loss: 29.2632 - val_mae: 3.6927
# Epoch 41/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 20.5390 - mae: 3.2497 - val_loss: 29.5531 - val_mae: 3.7047
# Epoch 42/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 30.1430 - mae: 3.7590 - val_loss: 29.5853 - val_mae: 3.7195
# Epoch 43/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 29.7938 - mae: 3.7272 - val_loss: 29.0997 - val_mae: 3.6954
# Epoch 44/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 25.2387 - mae: 3.5416 - val_loss: 28.7511 - val_mae: 3.6690
# Epoch 45/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 24.8278 - mae: 3.6177 - val_loss: 29.1055 - val_mae: 3.6952
# Epoch 46/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.2788 - mae: 3.4272 - val_loss: 28.6787 - val_mae: 3.6741
# Epoch 47/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.3074 - mae: 3.4323 - val_loss: 28.5450 - val_mae: 3.6716
# Epoch 48/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 32.0921 - mae: 3.8229 - val_loss: 28.5868 - val_mae: 3.6845
# Epoch 49/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 25.5113 - mae: 3.5416 - val_loss: 28.9634 - val_mae: 3.7132
# Epoch 50/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 25.7019 - mae: 3.4655 - val_loss: 28.4078 - val_mae: 3.6786
# Epoch 51/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 29.9736 - mae: 3.7427 - val_loss: 28.2020 - val_mae: 3.6667
# Epoch 52/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 25.7693 - mae: 3.5288 - val_loss: 28.7661 - val_mae: 3.7017
# Epoch 53/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 27.1066 - mae: 3.6510 - val_loss: 27.9158 - val_mae: 3.6660
# Epoch 54/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.9707 - mae: 3.5503 - val_loss: 28.2575 - val_mae: 3.6758
# Epoch 55/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 24.2817 - mae: 3.5575 - val_loss: 28.5417 - val_mae: 3.6973
# Epoch 56/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.6374 - mae: 3.3859 - val_loss: 27.7651 - val_mae: 3.6635
# Epoch 57/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 24.0161 - mae: 3.4280 - val_loss: 27.7145 - val_mae: 3.6669
# Epoch 58/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 26.1751 - mae: 3.5396 - val_loss: 28.3846 - val_mae: 3.6987
# Epoch 59/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 24.8491 - mae: 3.4778 - val_loss: 27.8412 - val_mae: 3.6726
# Epoch 60/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 22.3808 - mae: 3.3428 - val_loss: 27.8411 - val_mae: 3.6728
# Epoch 61/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 24.7595 - mae: 3.5298 - val_loss: 28.0924 - val_mae: 3.6929
# Epoch 62/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 22.8523 - mae: 3.3930 - val_loss: 27.5001 - val_mae: 3.6656
# Epoch 63/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 23.1833 - mae: 3.4142 - val_loss: 27.7810 - val_mae: 3.6827
# Epoch 64/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 23.1779 - mae: 3.3908 - val_loss: 27.5477 - val_mae: 3.6742
# Epoch 65/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 25.4538 - mae: 3.6582 - val_loss: 27.7495 - val_mae: 3.6842
# Epoch 66/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 25.3754 - mae: 3.6586 - val_loss: 28.1182 - val_mae: 3.6991
# Epoch 67/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 22.9396 - mae: 3.4028 - val_loss: 27.1094 - val_mae: 3.6548
# Epoch 68/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 24.7898 - mae: 3.5322 - val_loss: 27.6938 - val_mae: 3.6808
# Epoch 69/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 21.3323 - mae: 3.2955 - val_loss: 27.3735 - val_mae: 3.6643
# Epoch 70/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 27.9678 - mae: 3.7041 - val_loss: 27.1751 - val_mae: 3.6535
# Epoch 71/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 23.3391 - mae: 3.5755 - val_loss: 27.6175 - val_mae: 3.6643
# Epoch 72/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.8425 - mae: 3.3800 - val_loss: 27.5148 - val_mae: 3.6557
# Epoch 73/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.7189 - mae: 3.4200 - val_loss: 27.0543 - val_mae: 3.6456
# Epoch 74/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 22.1712 - mae: 3.3450 - val_loss: 27.6310 - val_mae: 3.6712
# Epoch 75/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 29.1440 - mae: 3.7724 - val_loss: 27.0875 - val_mae: 3.6414
# Epoch 76/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 24.0344 - mae: 3.5164 - val_loss: 27.3849 - val_mae: 3.6596
# Epoch 77/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 30.7126 - mae: 3.8113 - val_loss: 27.4395 - val_mae: 3.6656
# Epoch 78/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 29.4289 - mae: 3.7790 - val_loss: 27.6612 - val_mae: 3.6764
# Epoch 79/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 29.3493 - mae: 3.7277 - val_loss: 26.8419 - val_mae: 3.6302
# Epoch 80/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 24.8429 - mae: 3.4255 - val_loss: 27.3678 - val_mae: 3.6431
# Epoch 81/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 23.1811 - mae: 3.4407 - val_loss: 27.2937 - val_mae: 3.6371
# Epoch 82/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.5135 - mae: 3.3602 - val_loss: 26.6248 - val_mae: 3.6241
# Epoch 83/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 24.1011 - mae: 3.5153 - val_loss: 27.3451 - val_mae: 3.6549
# Epoch 84/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 26.6703 - mae: 3.5707 - val_loss: 26.9623 - val_mae: 3.6223
# Epoch 85/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.4783 - mae: 3.4631 - val_loss: 26.9098 - val_mae: 3.6178
# Epoch 86/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 25.8381 - mae: 3.4472 - val_loss: 26.8338 - val_mae: 3.6135
# Epoch 87/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 22.4047 - mae: 3.3413 - val_loss: 27.2324 - val_mae: 3.6373
# Epoch 88/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 25.6020 - mae: 3.5426 - val_loss: 26.7693 - val_mae: 3.6067
# Epoch 89/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 19.3713 - mae: 3.2272 - val_loss: 27.1731 - val_mae: 3.6287
# Epoch 90/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 19.6415 - mae: 3.2012 - val_loss: 26.6403 - val_mae: 3.6028
# Epoch 91/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 28.6657 - mae: 3.6268 - val_loss: 26.9399 - val_mae: 3.6162
# Epoch 92/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 26.3554 - mae: 3.5983 - val_loss: 26.9551 - val_mae: 3.6122
# Epoch 93/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 25.5770 - mae: 3.5966 - val_loss: 26.7404 - val_mae: 3.6023
# Epoch 94/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 23.8904 - mae: 3.5837 - val_loss: 26.8500 - val_mae: 3.6030
# Epoch 95/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 26.3029 - mae: 3.6159 - val_loss: 26.5279 - val_mae: 3.5930
# Epoch 96/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 23.1425 - mae: 3.4759 - val_loss: 27.2015 - val_mae: 3.6272
# Epoch 97/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 26.1941 - mae: 3.5565 - val_loss: 26.6307 - val_mae: 3.5905
# Epoch 98/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 23.8943 - mae: 3.5236 - val_loss: 26.6259 - val_mae: 3.5864
# Epoch 99/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 25.3819 - mae: 3.5321 - val_loss: 26.7587 - val_mae: 3.5948
# Epoch 100/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.6902 - mae: 3.4273 - val_loss: 26.6802 - val_mae: 3.5831
# history.keys =  dict_keys(['loss', 'mae', 'val_loss', 'val_mae'])
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step

# %%
plotPredictionsSeparated(predicted_value, X_test, y_test)
# Out:
# (array([6.849, 6.696, 6.03 , 5.878, 5.362, 6.372, 6.63 , 6.072, 5.951,
#         6.417, 6.75 , 6.874, 5.731, 5.787, 6.023, 5.608, 6.649, 8.725,
#         6.162, 4.926, 5.705, 5.628, 6.567, 6.415, 6.29 , 5.896, 6.096,
#         6.014, 7.52 , 5.39 , 6.579, 5.605, 8.034, 6.251, 6.144, 5.926,
#         6.341, 7.147, 4.138, 6.114, 6.333, 6.31 , 6.618, 6.162, 6.185,
#         6.824, 7.802, 5.887, 6.101, 6.405, 6.98 ]),
#  array([ 7.53,  7.18, 18.8 ,  8.1 , 10.19, 11.12,  4.7 , 13.04, 17.92,
#          8.81,  7.74,  4.61, 13.61, 10.24, 11.72, 12.13, 23.24,  4.63,
#          7.43, 29.53, 11.5 , 16.65,  9.28,  6.12,  4.67, 24.39, 20.34,
#         10.53,  7.26, 20.85,  5.49, 18.46,  2.88, 16.44,  9.09, 13.59,
#         17.79,  5.33, 23.34, 14.98,  7.34,  6.75,  7.6 , 24.1 , 18.03,
#         22.74,  1.92, 16.35,  9.81, 10.63, 11.66]))

# %% [markdown]
# ### **Modelo 2**
#
# #### 13 features de entrenamiento

# %%
# Prueba 2 --> 13 datos como features
X1 = boston_df[["crim", "zn" , "indus", "chas", "nox", "rm", "age", "dis", "rad", "tax", "ptratio", "b", "lstat"]]
y1 = boston_df["medv"]  # no es lo mismo que tenga 1 par de corchetes o dos pares de corchetes
model1, X1_train, X1_test, y1_train, y1_test = myModel(X1, y1, random_state=1, scale=True)
trainMyModel(model1, X1_train, y1_train)
predicted_value1 = makePredictions(model1, X1_test, y1_test)
data21, data22 = plotPredictionsOnTwoAxes(predicted_value1, X1_test, y1_test)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 128)            │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,921 (7.50 KB)
#  Trainable params: 1,921 (7.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 573.3082 - mae: 22.3782 - val_loss: 544.5821 - val_mae: 21.3188
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 588.1257 - mae: 22.4661 - val_loss: 516.9364 - val_mae: 20.7224
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 508.0228 - mae: 20.8686 - val_loss: 488.3243 - val_mae: 20.0737
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 485.5065 - mae: 20.3169 - val_loss: 457.2851 - val_mae: 19.3589
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 471.1174 - mae: 19.9603 - val_loss: 422.7406 - val_mae: 18.5575
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 436.4978 - mae: 19.0128 - val_loss: 386.2621 - val_mae: 17.6855
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 356.7489 - mae: 17.2343 - val_loss: 347.7518 - val_mae: 16.7179
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 363.7831 - mae: 17.2163 - val_loss: 307.7248 - val_mae: 15.6409
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 279.7324 - mae: 14.9120 - val_loss: 269.2083 - val_mae: 14.5213
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 259.8160 - mae: 14.1774 - val_loss: 232.4956 - val_mae: 13.3540
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 229.3307 - mae: 13.2678 - val_loss: 199.3384 - val_mae: 12.2381
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 194.1120 - mae: 11.8318 - val_loss: 169.8495 - val_mae: 11.2124
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 168.7993 - mae: 10.8248 - val_loss: 145.4634 - val_mae: 10.2306
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 137.7760 - mae: 9.5099 - val_loss: 124.5296 - val_mae: 9.3446
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 114.6526 - mae: 8.7033 - val_loss: 107.5583 - val_mae: 8.5310
# Epoch 16/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 103.7230 - mae: 8.4055 - val_loss: 93.8586 - val_mae: 7.8196
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 94.6399 - mae: 7.8341 - val_loss: 82.7099 - val_mae: 7.2128
# Epoch 18/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 76.2453 - mae: 7.1928 - val_loss: 73.2817 - val_mae: 6.6676
# Epoch 19/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 67.7112 - mae: 6.4987 - val_loss: 65.5542 - val_mae: 6.2173
# Epoch 20/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 63.3153 - mae: 6.2278 - val_loss: 59.0733 - val_mae: 5.8267
# Epoch 21/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 53.1992 - mae: 5.6652 - val_loss: 53.7525 - val_mae: 5.5062
# Epoch 22/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 45.9414 - mae: 5.2349 - val_loss: 49.1199 - val_mae: 5.2188
# Epoch 23/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 43.0963 - mae: 5.0031 - val_loss: 45.2613 - val_mae: 4.9523
# Epoch 24/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 37.0330 - mae: 4.4866 - val_loss: 41.9321 - val_mae: 4.7213
# Epoch 25/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 30.1230 - mae: 4.2161 - val_loss: 39.2969 - val_mae: 4.5405
# Epoch 26/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 36.3255 - mae: 4.5881 - val_loss: 37.0594 - val_mae: 4.3774
# Epoch 27/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 33.7189 - mae: 4.3160 - val_loss: 35.2035 - val_mae: 4.2435
# Epoch 28/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 32.3145 - mae: 4.3424 - val_loss: 33.7563 - val_mae: 4.1464
# Epoch 29/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 30.3356 - mae: 4.0382 - val_loss: 32.5480 - val_mae: 4.0645
# Epoch 30/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 27.2167 - mae: 3.8341 - val_loss: 31.5774 - val_mae: 3.9842
# Epoch 31/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 28.8505 - mae: 3.9550 - val_loss: 30.6981 - val_mae: 3.9142
# Epoch 32/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 29.3336 - mae: 3.8577 - val_loss: 29.9593 - val_mae: 3.8566
# Epoch 33/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 24.9534 - mae: 3.8557 - val_loss: 29.3112 - val_mae: 3.8039
# Epoch 34/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 24.6678 - mae: 3.6920 - val_loss: 28.6781 - val_mae: 3.7658
# Epoch 35/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 29.3133 - mae: 3.8916 - val_loss: 28.1931 - val_mae: 3.7312
# Epoch 36/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 24.4328 - mae: 3.7226 - val_loss: 27.6925 - val_mae: 3.6970
# Epoch 37/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 24.5307 - mae: 3.6465 - val_loss: 27.3254 - val_mae: 3.6708
# Epoch 38/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 22.2402 - mae: 3.5549 - val_loss: 26.9006 - val_mae: 3.6452
# Epoch 39/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.7049 - mae: 3.5472 - val_loss: 26.5744 - val_mae: 3.6146
# Epoch 40/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 22.1390 - mae: 3.4997 - val_loss: 26.2747 - val_mae: 3.5873
# Epoch 41/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 24.3841 - mae: 3.6204 - val_loss: 25.9343 - val_mae: 3.5718
# Epoch 42/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 25.1921 - mae: 3.6033 - val_loss: 25.6452 - val_mae: 3.5540
# Epoch 43/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 24.6720 - mae: 3.4554 - val_loss: 25.3426 - val_mae: 3.5299
# Epoch 44/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 23.6933 - mae: 3.5679 - val_loss: 25.0973 - val_mae: 3.5044
# Epoch 45/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 20.0612 - mae: 3.2958 - val_loss: 24.7995 - val_mae: 3.4733
# Epoch 46/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 24.4150 - mae: 3.5540 - val_loss: 24.5022 - val_mae: 3.4537
# Epoch 47/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 20.3657 - mae: 3.1879 - val_loss: 24.2764 - val_mae: 3.4309
# Epoch 48/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 20.7142 - mae: 3.3921 - val_loss: 24.0479 - val_mae: 3.4069
# Epoch 49/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 19.6007 - mae: 3.2325 - val_loss: 23.8098 - val_mae: 3.3791
# Epoch 50/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 16.9568 - mae: 3.0740 - val_loss: 23.4352 - val_mae: 3.3537
# Epoch 51/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 20.1566 - mae: 3.3045 - val_loss: 23.2167 - val_mae: 3.3247
# Epoch 52/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 21.4813 - mae: 3.2731 - val_loss: 22.9386 - val_mae: 3.3082
# Epoch 53/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 18.1834 - mae: 3.1575 - val_loss: 22.6972 - val_mae: 3.2891
# Epoch 54/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 17.8204 - mae: 3.0554 - val_loss: 22.5289 - val_mae: 3.2639
# Epoch 55/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 16.7391 - mae: 3.0897 - val_loss: 22.2889 - val_mae: 3.2411
# Epoch 56/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 17.0980 - mae: 3.0510 - val_loss: 22.0489 - val_mae: 3.2198
# Epoch 57/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 17.8553 - mae: 3.0640 - val_loss: 21.7236 - val_mae: 3.1974
# Epoch 58/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 17.7628 - mae: 3.0920 - val_loss: 21.5029 - val_mae: 3.1596
# Epoch 59/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.9311 - mae: 3.0920 - val_loss: 21.2790 - val_mae: 3.1323
# Epoch 60/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 15.5509 - mae: 2.9427 - val_loss: 21.0641 - val_mae: 3.1192
# Epoch 61/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 15.3771 - mae: 2.8956 - val_loss: 20.8294 - val_mae: 3.1073
# Epoch 62/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 17.7228 - mae: 3.0867 - val_loss: 20.5857 - val_mae: 3.0809
# Epoch 63/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 14.9393 - mae: 2.8298 - val_loss: 20.3613 - val_mae: 3.0524
# Epoch 64/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 15.2383 - mae: 2.9257 - val_loss: 20.1701 - val_mae: 3.0294
# Epoch 65/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.3148 - mae: 2.7792 - val_loss: 19.9665 - val_mae: 3.0201
# Epoch 66/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.9954 - mae: 2.8265 - val_loss: 19.6969 - val_mae: 3.0045
# Epoch 67/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.8185 - mae: 2.8161 - val_loss: 19.5669 - val_mae: 2.9758
# Epoch 68/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 15.2105 - mae: 2.8126 - val_loss: 19.3737 - val_mae: 2.9543
# Epoch 69/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 13.3674 - mae: 2.7297 - val_loss: 19.1806 - val_mae: 2.9299
# Epoch 70/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 15.5887 - mae: 2.7914 - val_loss: 19.0047 - val_mae: 2.9078
# Epoch 71/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 12.2720 - mae: 2.5723 - val_loss: 18.7558 - val_mae: 2.8812
# Epoch 72/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 14.1528 - mae: 2.7459 - val_loss: 18.5758 - val_mae: 2.8639
# Epoch 73/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.2480 - mae: 2.7197 - val_loss: 18.4007 - val_mae: 2.8408
# Epoch 74/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 15.7057 - mae: 2.7955 - val_loss: 18.2052 - val_mae: 2.8177
# Epoch 75/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 13.5245 - mae: 2.6563 - val_loss: 18.0010 - val_mae: 2.8031
# Epoch 76/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.4669 - mae: 2.7372 - val_loss: 17.8895 - val_mae: 2.7768
# Epoch 77/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 14.4296 - mae: 2.6742 - val_loss: 17.7705 - val_mae: 2.7398
# Epoch 78/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 13.7700 - mae: 2.7840 - val_loss: 17.5687 - val_mae: 2.7280
# Epoch 79/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 12.0025 - mae: 2.5148 - val_loss: 17.3128 - val_mae: 2.7127
# Epoch 80/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 11.9270 - mae: 2.5394 - val_loss: 17.1741 - val_mae: 2.6883
# Epoch 81/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 12.5179 - mae: 2.5689 - val_loss: 16.9925 - val_mae: 2.6628
# Epoch 82/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 12.3701 - mae: 2.4812 - val_loss: 16.8205 - val_mae: 2.6581
# Epoch 83/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 13.0528 - mae: 2.5929 - val_loss: 16.6884 - val_mae: 2.6493
# Epoch 84/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 12.2668 - mae: 2.4890 - val_loss: 16.4861 - val_mae: 2.6298
# Epoch 85/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 11.7514 - mae: 2.5221 - val_loss: 16.3753 - val_mae: 2.6106
# Epoch 86/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 14.5175 - mae: 2.6856 - val_loss: 16.2330 - val_mae: 2.6071
# Epoch 87/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.0345 - mae: 2.6680 - val_loss: 16.1924 - val_mae: 2.6033
# Epoch 88/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 12.3523 - mae: 2.5497 - val_loss: 16.0512 - val_mae: 2.6012
# Epoch 89/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 14.8387 - mae: 2.6352 - val_loss: 15.9610 - val_mae: 2.5894
# Epoch 90/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 15.0353 - mae: 2.6758 - val_loss: 15.8336 - val_mae: 2.5770
# Epoch 91/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 14.1185 - mae: 2.5956 - val_loss: 15.7540 - val_mae: 2.5724
# Epoch 92/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 11.2573 - mae: 2.3524 - val_loss: 15.5974 - val_mae: 2.5577
# Epoch 93/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 13.1766 - mae: 2.5526 - val_loss: 15.5163 - val_mae: 2.5436
# Epoch 94/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 13.3028 - mae: 2.5008 - val_loss: 15.3926 - val_mae: 2.5410
# Epoch 95/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 13.7041 - mae: 2.5839 - val_loss: 15.3406 - val_mae: 2.5483
# Epoch 96/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 11.9650 - mae: 2.4632 - val_loss: 15.2569 - val_mae: 2.5301
# Epoch 97/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.9257 - mae: 2.3322 - val_loss: 15.1424 - val_mae: 2.5300
# Epoch 98/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 14.4565 - mae: 2.6191 - val_loss: 15.0679 - val_mae: 2.5200
# Epoch 99/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 12.2902 - mae: 2.4862 - val_loss: 14.9670 - val_mae: 2.5246
# Epoch 100/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 11.1128 - mae: 2.2765 - val_loss: 14.8928 - val_mae: 2.5226
# history.keys =  dict_keys(['loss', 'mae', 'val_loss', 'val_mae'])
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step

# %%
plotPredictionsSeparated(predicted_value1, X1_test, y1_test)
# Out:
# (array([ 0.80948285,  0.59035789, -0.36348021, -0.58117299, -1.32018269,
#          0.12632854,  0.49583339, -0.30332826, -0.47662317,  0.19077706,
#          0.66769611,  0.84528759, -0.79170482, -0.71150222, -0.37350554,
#         -0.96786411,  0.52304499,  3.49627005, -0.17443122, -1.94461723,
#         -0.82894174, -0.93922032,  0.40560546,  0.18791268,  0.00888902,
#         -0.55539358, -0.26895571, -0.38639524,  1.7704819 , -1.28008138,
#          0.42279173, -0.97216068,  2.50662722, -0.04696637, -0.20021063,
#         -0.5124279 ,  0.08193067,  1.23627528, -3.07318243, -0.24317631,
#          0.07047316,  0.0375328 ,  0.47864712, -0.17443122, -0.14149086,
#          0.77367812,  2.17435929, -0.56828328, -0.26179477,  0.17359079,
#          0.99709966]),
#  array([-0.71650549, -0.76509904,  0.84820699, -0.63736741, -0.34719447,
#         -0.21807445, -1.10941909,  0.04849591,  0.72602891, -0.53879192,
#         -0.68734936, -1.12191458,  0.12763399, -0.34025253, -0.13477121,
#         -0.07784733,  1.46465095, -1.1191378 , -0.73038936,  2.33794656,
#         -0.16531573,  0.54970372, -0.47353771, -0.9122681 , -1.11358425,
#          1.62431549,  1.06201864, -0.2999893 , -0.75399195,  1.13282639,
#         -0.9997365 ,  0.80100182, -1.36210558,  0.52054759, -0.49991707,
#          0.12485721,  0.70797988, -1.02195069,  1.47853482,  0.31784305,
#         -0.74288485, -0.8247997 , -0.70678678,  1.58405226,  0.74130117,
#          1.39523159, -1.49539076,  0.5080521 , -0.39995319, -0.28610543,
#         -0.14310154]))

# %% [markdown]
# ### Ploteamos los resultados de los dos modelos

# %%
plotTwoModels(data11, data12, y_test, predicted_value, data21, data22, predicted_value1)
